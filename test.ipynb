# %%
from stock import Stock

# %%
msft = Stock('MSFT')
preds = msft.predict()
prec = msft.precision(preds)
print(prec)
# Out:
# MSFT
# data/msft_data.json
# 0.5721925133689839

# %%
msft.plot_hist()
# Out:
# <AxesSubplot:>

# %%
msft.plot_preds(preds, 100)
# Out:
# <AxesSubplot:>

# %%
preds["Target"].value_counts()
# Out:
# 1.0    3905
# 0.0    3811
# Name: Target, dtype: int64

# %%
preds["Predictions"].value_counts()
# Out:
# 0.0    7529
# 1.0     187
# Name: Predictions, dtype: int64

# %%
rivn = Stock('RIVN')
preds = rivn.predict()
prec = rivn.precision(preds)
print(prec)
# Out:
# RIVN
# data/rivn_data.json
# 0.5534591194968553

# %%
rivn.plot_hist()
# Out:
# <AxesSubplot:>
